# %% [markdown]
# # MATPLOTLIB
# # 22341

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
os.chdir("D:/Pandas")

car=pd.read_csv("Toyota.csv", index_col=0,na_values=['??','????'])	#set first column as index, remove ??, ???? values
car.dropna(axis=0,inplace=True)
print(car)

# %%
plt.scatter(car['Age'], car['Price'], c='blue' )
plt.title("My Plot")
plt.xlabel("Age in Months")
plt.ylabel("Price in Euros")
plt.show()

# %%
plt.hist(car['KM'],color='red',edgecolor = 'black',bins=5)
plt.title("My Plot")
plt.xlabel("KM")
plt.ylabel("Frequency")
plt.show()

# %%
car['FuelType'].value_counts()
counts = [968,116,12]
FT = ('Petrol','Diesel','CNG')
index = np.arange(len(FT))

plt.bar(index,counts,color = ['yellow','green','orange'])
plt.title("My bar graph")
plt.xlabel("Fuel Type")
plt.ylabel("Freq")
plt.xticks(index,FT,rotation = 90)
plt.show()

# %%
#Line chart

x = np.array( range(0,10))  # X-axis points
y = x*2  # Y-axis points
  
plt.plot(x, y)  # Plot the chart
plt.show()  # display
'''

plt.plot(car['Age'],car['Price'])
plt.title("My Line graph")
plt.xlabel("")
plt.ylabel("")
plt.show()

'''
# Out:
# '\n\nplt.plot(car[\'Age\'],car[\'Price\'])\nplt.title("My Line graph")\nplt.xlabel("")\nplt.ylabel("")\nplt.show()\n\n'

# %%
#BOXPLOT

plt.boxplot(car['Age'])
plt.title("My boxplot graph")
plt.xlabel("Age")
plt.ylabel("Freq")
plt.show()

# %%
#HEATMAP
data = np.random.random(( 10 , 10 ))
plt.imshow( data , cmap = 'autumn' , interpolation = 'nearest' )
'''
plt.imshow((car['KM'],car['Age']))
plt.show()
'''
# Out:
# "\nplt.imshow((car['KM'],car['Age']))\nplt.show()\n"
